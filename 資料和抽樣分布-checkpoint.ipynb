# %%
from pathlib import Path
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.utils import resample

import seaborn as sns
import matplotlib.pylab as plt

try:
    import common
    DATA = common.dataDirectory()
except ImportError:
    DATA = Path().resolve() / 'data'

# %%
# 母體與樣本
# 延伸閱讀選擇偏差 oreil.ly/v_Q0u 
np.random.seed(seed=1)
x = np.linspace(-3, 3, 300) # 均勻撒點(-3 至 3之間300點)
xsample = stats.norm.rvs(size=1000) # 生成隨機數

fig, axes = plt.subplots(ncols=2, figsize=(5, 1.5))

ax = axes[0]
ax.fill(x, stats.norm.pdf(x))
ax.set_axis_off()
ax.set_xlim(-3, 3)

ax = axes[1]
ax.hist(xsample, bins=30)
ax.set_axis_off()
ax.set_xlim(-3, 3)
ax.set_position
# plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0)

plt.show()

# %% [markdown]
# # 統計量的抽樣分布

# %%
# 簡單隨機抽樣 oreil.ly/pe7ra

loans_income = pd.read_csv('loans_income.csv').squeeze('columns')

sample_data = pd.DataFrame({
    'income': loans_income.sample(1000),
    'type': 'Data',
})

#1000個由5個數產生的平均數的均值樣本
sample_mean_05 = pd.DataFrame({
    'income': [loans_income.sample(5).mean() for _ in range(1000)],
    'type': 'Mean of 5',
})

sample_mean_20 = pd.DataFrame({
    'income': [loans_income.sample(20).mean() for _ in range(1000)],
    'type': 'Mean of 20',
})

results = pd.concat([sample_data, sample_mean_05, sample_mean_20])
print(results.head())

g = sns.FacetGrid(results, col='type', col_wrap=1, 
                  height=2, aspect=2)
g.map(plt.hist, 'income', range=[0, 200000], bins=40)
g.set_axis_labels('Income', 'Count')
g.set_titles('{col_name}')

plt.tight_layout()
plt.show()
#中央極限定理:樣本越大越接近常態分佈，但資料科學常用bootstrap
#若樣本規模增加4倍，標準誤差會縮小一半
#標準差=各個資料變異性/標準誤差=抽樣指標的變異性
# Out:
#          income  type
# 40292   63000.0  Data
# 38959   92000.0  Data
# 17361  134000.0  Data
# 33996   52000.0  Data
# 26491   43000.0  Data

# %% [markdown]
# # The Boostrap

# %%
results = []
for nrepeat in range(1000):
    sample = resample(loans_income) #scikit-learn.resample
    results.append(sample.median())
results = pd.Series(results)
print('Bootstrap Statistics:')
print(f'original: {loans_income.median()}') #中位數
print(f'bias: {results.mean() - loans_income.median()}') #偏差
print(f'std. error: {results.std()}') #標準誤差
# Out:
# Bootstrap Statistics:
# original: 62000.0
# bias: -82.09799999999814
# std. error: 228.73933106830748

# %% [markdown]
# # 信賴區間

# %%
print(loans_income.mean())
np.random.seed(seed=3)
# create a sample of 20 loan income data
sample20 = resample(loans_income, n_samples=20, replace=False)
print(sample20.mean())

results = []
for nrepeat in range(500):
    sample = resample(sample20)
    results.append(sample.mean())
results = pd.Series(results)

confidence_interval = list(results.quantile([0.05, 0.95]))
ax = results.plot.hist(bins=30, figsize=(4, 3))
ax.plot(confidence_interval, [55, 55], color='black')
for x in confidence_interval:
    ax.plot([x, x], [0, 65], color='black')
    ax.text(x, 70, f'{x:.0f}',
            horizontalalignment='center', verticalalignment='center')
ax.text(sum(confidence_interval) / 2, 60, '90% interval',
        horizontalalignment='center', verticalalignment='center')

meanIncome = results.mean()
ax.plot([meanIncome, meanIncome], [0, 50], color='black', linestyle='--')
ax.text(meanIncome, 10, f'Mean: {meanIncome:.0f}',
        bbox=dict(facecolor='white', edgecolor='white', alpha=0.5),
        horizontalalignment='center', verticalalignment='center')
ax.set_ylim(0, 80)
ax.set_ylabel('Counts')

plt.tight_layout()
plt.show()

np.random.seed(seed=3)
# create a sample of 20 loan income data
sample20 = resample(loans_income, n_samples=20, replace=False)

results = []
for nrepeat in range(500):
    sample = resample(sample20)
    results.append(sample.mean())
results = pd.Series(results)

confidence_interval = list(results.quantile([0.05, 0.95]))
ax = results.plot.hist(bins=30, figsize=(4, 3), color='C1')
ax.plot(confidence_interval, [55, 55], color='black', linestyle='--')
for x in confidence_interval:
    ax.plot([x, x], [0, 60], color='black')
ax.text(82000, 50,
        f'90% CI\n[{confidence_interval[0]:.0f}, {confidence_interval[1]:.0f}]',
        fontsize='small')

confidence_interval = list(results.quantile([0.025, 0.975]))
ax = results.plot.hist(bins=30, figsize=(4, 3))
ax.plot(confidence_interval, [65, 65], color='black', linestyle='--')
for x in confidence_interval:
    ax.plot([x, x], [0, 70], color='black')
ax.text(82000, 65,
        f'95% CI\n[{confidence_interval[0]:.0f}, {confidence_interval[1]:.0f}]',
        fontsize='small')
# ax.text(sum(confidence_interval) / 2, 264, '95 % interval',
#         horizontalalignment='center', verticalalignment='center')

meanIncome = results.mean()
ax.plot([meanIncome, meanIncome], [0, 50], color='black', linestyle='--')
ax.text(meanIncome, 5, f'Mean: {meanIncome:.0f}',
        bbox=dict(facecolor='white', edgecolor='white', alpha=0.5),
        horizontalalignment='center', verticalalignment='center')
ax.set_ylim(0, 80)
ax.set_xlim(37000, 102000)
ax.set_xticks([40000, 50000, 60000, 70000, 80000])
ax.set_ylabel('Counts')

plt.tight_layout()
plt.show()
# Out:
# 68760.51844
# 55734.1

# %%
# QQ圖
fig, ax = plt.subplots(figsize=(4, 4))

norm_sample = stats.norm.rvs(size=100)
stats.probplot(norm_sample, plot=ax)

plt.tight_layout()
plt.show()
# 越接近對角線越是常態分佈

# %%
# 長尾分布(黑天鵝)
sp500_px = pd.read_csv('sp500_data.csv.gz')

nflx = sp500_px.NFLX
nflx = np.diff(np.log(nflx[nflx > 0]))

fig, ax = plt.subplots(figsize=(4, 4))
stats.probplot(nflx, plot=ax)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 二項分布 oreil.ly/nmkcs

# %%
n = 5
p = 0.1
print(stats.binom.pmf(2, n, p))  # 在5次成功機率為0.1的實驗中，成功2次的機率

print(stats.binom.cdf(2, n, p))  # 在5次成功機率為0.1的實驗中，成功次數不到2次的機率

print(f'平均值或稱為{n}次試驗的期望成功次數: {n*p}，其中每次試驗成功的機率是{p}')
print(f'變異數為: {n*p*(1-p)}')
# Out:
# 0.07289999999999992
# 0.99144
# 平均值或稱為5次試驗的期望成功次數: 0.5，其中每次試驗成功的機率是0.1
# 變異數為: 0.45

# %% [markdown]
# # 松柏分布

# %%
# 松柏分布(單位時空內，事件數量的分布)
# e.x. 平均每分鐘有兩通電話，模擬100通，並顯示每分鐘的次數
sample = stats.poisson.rvs(2, size=100)  # lambda=2的松柏分布產生100個隨機數

pd.Series(sample).plot.hist()
plt.show()

# %%
# 指數分布(單位時空內，前後事件的頻率分布)
# e.x. 平均每分鐘有0.2通電話，模擬100通，並顯示時間間隔
sample = stats.expon.rvs(scale=1/0.2, size=100)

pd.Series(sample).plot.hist()
plt.show()

# %%
#韋伯分布(廣義指數分布，事件發生機率會隨著時間變化而變化，用來分析發生事件的時間)
sample = stats.weibull_min.rvs(1.5, scale=5000, size=100) 
#(形狀參數>1代表發生機率會隨著時間增加而增加/特徵生命週期/隨機數字)

pd.Series(sample).plot.hist()
plt.show()
